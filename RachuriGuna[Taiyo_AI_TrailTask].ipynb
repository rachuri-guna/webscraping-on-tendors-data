# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.gov.uk/contracts-finder/"
page = requests.get(URL)
print(page.content)

soup = BeautifulSoup(page.content, "html.parser")
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 9]><html class="lte-ie8 govuk-template" lang="en"><![endif]--><!--[if gt IE 8]><!--><html class="govuk-template" lang="en">\n<!--<![endif]-->\n  <head>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta property="og:description" content="Use Contracts Finder to find out about current contract opportunities with the government and its agencies">\n<meta property="og:title" content="Contracts Finder">\n<meta property="og:url" content="https://www.gov.uk/contracts-finder">\n<meta property="og:type" content="article">\n<meta property="og:site_name" content="GOV.UK">\n<meta property="og:description" content="Use Contracts Finder to find out about current contract opportunities with the government and its agencies">\n<meta property="og:title" content="Contracts Finder">\n<meta property="og:url" content="https://www.gov.uk/contracts-finder">\n<meta property="og:type" content="article">\n<meta property="og:site_name" content="GOV.UK">\n<meta name="govuk:section" content="business and self-employed">\n<meta name="govuk:taxon-slugs" content="sale-goods-services-data">\n<meta name="govuk:taxon-slug" content="sale-goods-services-data">\n<meta name="govuk:taxon-ids" content="c39ac533-be2c-4460-93ba-e656793568ef">\n<meta name="govuk:taxon-id" content="c39ac533-be2c-4460-93ba-e656793568ef">\n<meta name="govuk:themes" content="business-and-industry">\n<meta name="govuk:analytics:organisations" content="&lt;D2&gt;&lt;EA1015&gt;">\n<meta name="govuk:primary-publishing-organisation" content="Government Digital Service">\n<meta name="govuk:public-updated-at" content="2017-11-23T12:36:02.000+00:00">\n<meta name="govuk:updated-at" content="2022-08-03T10:13:36.313Z">\n<meta name="govuk:first-published-at" content="2012-10-16T21:24:11.000+00:00">\n<meta name="govuk:static-analytics:strip-postcodes" content="true">\n<meta name="govuk:content-id" content="8fa5f9aa-ae6f-4d77-a474-ef7246e91c63">\n<meta name="govuk:schema-name" content="transaction">\n<meta name="govuk:rendering-app" content="frontend">\n<meta name="govuk:publishing-app" content="publisher">\n<meta name="govuk:format" content="transaction">\n<meta name="description" content="Use Contracts Finder to find out about current contract opportunities with the government and its agencies">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:card" content="summary">\n    <meta charset="utf-8">\n    <title>Contracts Finder - GOV.UK</title>\n\n    <script src="https://www.gov.uk/assets/static/govuk_publishing_components/vendor/lux/lux-measurer-505eef3e243b1d08ea7c4b945ebe1ae146d896db61366e415b30cc1bcd84cbdc.js" async="async"></script>\n    <script src="https://www.gov.uk/assets/static/govuk_publishing_components/rum-loader-c53469dcb841d7b228c914a2e8bdcf3b831a578adf7d4f21cf9da5b85df7381e.js" async="async" data-lux-reporter-script="https://www.gov.uk/assets/static/govuk_publishing_components/vendor/lux/lux-reporter-0630526d2811f955ec5e421a6233bd828938bf706c2481233ef4efb8831d0625.js"></script>\n\n    \n\n    <link rel="stylesheet" href="https://www.gov.uk/assets/static/application-d1b60582aa28a0f0f6a7a752b335012f21e07e7147ee3e629510068f193bc3ff.css" media="all">\n    <link rel="stylesheet" href="https://www.gov.uk/assets/static/print-53da7f13c2fb1115b956c35ef5e0898aa48fd2e0457f82692fdf8d16ed2e2626.css" media="print">\n    <!--[if lt IE 9]><script src="https://www.gov.uk/assets/static/govuk_publishing_components/ie-94963d6661190bc897905bbbe222a31c7ca0aff3a3b9f808ba15d4cd90780a9b.js" crossorigin="anonymous" integrity="sha256-pFJFRKU9V6fiWbS7lmucMlV8mMkgt35S0JMEZCtoQBo="></script><![endif]-->\n    <link rel="shortcut icon" href="https://www.gov.uk/assets/static/favicon-9ed7849c462c53aa2cdf1690eb257e801ecbf5696d1d0928868c5b032b4adb36.ico" type="image/x-icon">\n    <link rel="mask-icon" href="https://www.gov.uk/assets/static/govuk-mask-icon-a409a4db4a5e72c99ae3916653710064c43eb4be35821f79c07c5156e7dc5808.svg" color="#0b0c0c">\n    <link ...

# %%
results = soup.find(id="before-you-start")

# %%
print(results)
# Out:
# <div id="before-you-start">
# <h2 class="gem-c-heading gem-c-heading--font-size-27 govuk-!-margin-bottom-4">Before you start</h2>
# <div class="gem-c-govspeak govuk-govspeak " data-module="govspeak">
# <p>Scotland, Wales and Northern Ireland have their own dedicated public sector procurement websites. These are:</p>
# <ul>
# <li>
# <a href="http://www.publiccontractsscotland.gov.uk/search/search_mainpage.aspx" rel="external">Public Contracts Scotland</a> for opportunities with public sector bodies in Scotland</li>
# <li>
# <a href="http://www.sell2wales.gov.uk" rel="external">Sell2Wales</a> for opportunities with public sector bodies in Wales</li>
# <li>
# <a href="https://e-sourcingni.bravosolution.co.uk/web/login.shtml" rel="external">eSourcing NI</a> and <a href="https://etendersni.gov.uk/epps/home.do" rel="external">eTendersNI</a> for opportunities with public sector bodies in Northern Ireland</li>
# </ul>
# </div>
# </div>

# %%
job_elements = results.find_all("div", class_="gem-c-govspeak govuk-govspeak ")

# %%
for i in soup.find_all('a', href = True):
  if("etenders" in i['href']):
    nextpage = requests.get(i['href'])
    nextsoup = BeautifulSoup(nextpage.content, 'html.parser')
    print("next url title : ",nextsoup.find('title').string)
    print(i['href'])
    next_URL=i['href']
# Out:
# next url title :  European Dynamics - Welcome to eTendersNI
# https://etendersni.gov.uk/epps/home.do

# %%
html_page1 = requests.get(next_URL).text
s = BeautifulSoup(html_page1,"html.parser")
print(s)
# Out:
# <!DOCTYPE html>
#
# <!-- ceproc.ok -->
# <html>
# <head>
# <!-- -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <title>European Dynamics - Welcome to eTendersNI</title>
# <meta content="e-Procurement platform home page" name="Description"/>
# <meta content="e-Procurement platform - Home page" name="Title"/>
# <meta content="57" name="Type"/>
# <meta content="DOCUMENTS/COMM/EN" name="Reference"/>
# <meta content="European Dynamics" name="Creator"/>
# <meta content="en" name="Language"/>
# <meta content="25" name="Classification"/>
# <meta content="tenders, e-procurement, documents, european law, legislation, economic operator, tenderer, procurement, contract, contracting authority, supplier, awarding authority, institutions, european union, eu" name="Keywords"/>
# <link href="images/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <script src="/epps/scripts/bt/jquery-1.11.3.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/popper.min.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/bootstrap.min.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/navScroll.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	        //<![CDATA[
# 	        var $j = jQuery.noConflict();
# 	        //]]>
#         </script>
# <script type="text/javascript">
# 			var PAGE_LITERAL = 'Page';
#     		var RESULTS_PER_PAGE_LITERAL = 'Results Per page';
#             var GOTO_PAGE_LITERAL = 'Goto Page';
#             var LOCALE = 'en';
#             var INVALID_CHARACTERS = '<>&%';
#         </script>
# <script src="/epps/scripts/common.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/common.js" type="text/javascript"></script>
# <script src="/epps/scripts/jqComm.js" type="text/javascript"></script>
# <script src="/epps/scripts/jqForm.js" type="text/javascript"></script>
# <script src="/epps/scripts/jqTableSet.js" type="text/javascript"></script>
# <script src="/epps/scripts/jquery-ui.js" type="text/javascript"></script>
# <script src="/epps/scripts/jquery.colorbox-min.js" type="text/javascript"></script>
# <script src="/epps/scripts/ed.custom.jqueryPlugin.openInModal.js" type="text/javascript"></script>
# <!-- -->
# <link href="https://cdnjs.cloudflare.com/ajax/libs/gijgo/1.7.0/combined/css/gijgo.min.css" rel="stylesheet" type="text/css"/>
# <link href="/epps/css/bt/bootstrap-datepicker3.min.css" media="screen" rel="stylesheet"/>
# <link href="/epps/css/bt/jquery.treefilter.css" rel="stylesheet"/>
# <script src="/epps/scripts/bt/bootstrap-datepicker.min.js" type="text/javascript"></script>
# <script src="/epps/scripts/jquery.formatCurrency-1.4.0.min.js" type="text/javascript"></script>
# <script src="/epps/scripts/jquery.formatCurrency.all.js" type="text/javascript"></script>
# <script type="text/javascript">
# 			// functions from bt/common.js
# 			$j(document).ready(function(){
# 				noResultFoundBeautifier();
# 				stackModeDataColumn();
# 				$j('.countdown').textCountdown({remaining_text: " remaining characters"});
# 				//TODO: modify to be enabled in internal sorting:
# 				// tableSawSortableStackMode();
# 			});
#
# 			function jcv_handleErrors(messages, focusField) {
#
# 			    if (focusField && focusField != null) {
# 			        var doFocus = true;
# 			        if (focusField.disabled || focusField.type == 'hidden') {
# 			            doFocus = false;
# 			        }
# 			        if (doFocus &&
# 			                focusField.style &&
# 			                focusField.style.visibility &&
# 			                focusField.style.visibility == 'hidden') {
# 			            doFocus = false;
# 			        }
# 			        if (doFocus) {
# 			            focusField.focus();
# 			        }
# 			    }
#
# 			    if ($j("#Message")) {
# 			        $j("#Message").remove();
# 			    }
# 			    var mesagesCont = document.createElement("div");
# 			    $j(mesagesCont)
# 			        .attr("id", "Message")
# 			        .addClass("alert alert-danger alert-dismissible");
#
# 			   	// Close "X"
# 				var closeButton = document.createElement("a");
# 			    $j(closeButton)
# 		        	.attr("href", "#")
# 		        	.attr('data-dismiss','alert')
# 		        	.attr('aria-label','close')
# 		        	.addClass('close');
# 			    $j(closeButton).html("&times;");
#
# 			    // The Error Message "An error has occurred:"
# 			   	var errorMSG = document.createElement("div");
# 			   	$j(errorMSG)
# 		            .addClass("row container-fluid")
# 	    	        .append(closeButton)
# 	                .append("<strong>An error has occurred:</strong>");
#
# 				// Div of col
# 				var divColMessages = document.createElement("div");
# 				$j(divColMessages)
# 					.addClass('col');
#
# 				// List of messages
# 			    var listMessages = document.createElement("ul");
# 			    for (i=0; i< messages.length; i++){
# 			    	$j(listMessages).append("<li>" + messages[i] + "</li>");
# 			    }
# 				// Append List inside col
# 			    $j(divColMessages)
# 		    		.append(listMessages);
# 			    $j(errorMSG).append(divColMessages);
#
# 			    // Append the errorMessage
# 			    // the close button
# 			    // the row of messages
# 			    $j(mesagesCont)
# 		       		.append(errorMSG)
# 		       		.append(closeButton);
#
# 			    $j("#msgCol")[0]
# 			        .appendChild(mesagesCont);
# 			}
# 		</script>
# <script type="text/javascript">
#             function setParentHref(link){
#                 window.location.href=link;
#             }
#
#             if(typeof String.prototype.trim !== 'function') {
# 	             String.prototype.trim = function() {
# 	            	  return this.replace(/^\s+|\s+$/g, '');
# 	             }
#              }
#         </script>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/epps/css/bt/custom.css" rel="stylesheet"/>
# <link href="/epps/css/jquery-ui.css" media="screen, projection" rel="stylesheet" type="text/css"/>
# <link href="/epps/css/bt/bootstrap-datetimepicker.css" rel="stylesheet"/>
# <link href="/epps/css/bt/mm-folder.css" rel="stylesheet"/>
# <script src="/epps/scripts/bt/tablesaw.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/tablesaw-init.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/jquery.treefilter.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/moment.min.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/bootstrap-datetimepicker.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/metisMenu.js" type="text/javascript"></script>
# <script src="/epps/scripts/bt/maincard.js" type="text/javascript"></script>
# </head>
# <body class="">
# <header>
# <nav class="navbar navbar-light bg-white navbar-expand-md p-0">
# <div class="flex-column col-12 p-0">
# <div class="row no-gutters p-2 align-items-center">
# <div class="col-6">
# <a class="navbar-brand mr-0 py-lg-1 py-xl-1 px-lg-2 px-xl-2" href="/epps">
# <img alt="Ηomepage" class="mr-lg-2 mr-xl-2 img-fluid " src="/epps/images/bt/NI-logo.gif"/>
# <img alt="Ηomepage" class="mr-lg-2 mr-xl-2 img-fluid d-none d-lg-inline-block" src="/epps/images/bt/NI-logo-2_1.png"/>
# </a>
# </div>
# <div class="col-6">
# <ul class="navbar-nav flex-row justify-content-end">
# <!-- Search -->
# <script type="text/javascript">
# 	function checkSubmit() {
# 		var	quicSearchForm = document.forms["quickSearchForm"];
# 		var col = document.getElementsByName("searchSelect")[0];
# 		if (col.selectedIndex != 0) {
# 			if(checkInputField(quicSearchForm))quicSearchForm.submit();
#     	}
#     	return false;
# 	}
#
# 	function checkInputField(form){
# 		var input = form[1].value;
# 		if(containForbidenChars(input)){
# 			form[1].value = '*';
# 			alert("An invalid character was provided for search. Invalid characters include: <, >, &, % .");
# 			return false;
# 		}
# 		return true;
# 	}
#
# 	function containForbidenChars(input){
#     	return input.indexOf("<")!=-1 || input.indexOf(">")!=-1 || input.indexOf("%")!=-1 || input.indexOf("&")!=-1;
#     }
# </script>
# <script type="text/javascript">
# 	$(document).ready(function() {
#
# 	});
#
# 	function openForm() {
# 		document.getElementById("simple-search").style.height = "100%";
# 	}
# 	function closeForm() {
# 		document.getElementById("simple-search").style.height = "0%";
# 	}
# </script>
# <li class="nav-item mr-2">
# <div>
# <a class="nav-link p-2" href="/epps/prepareAdvancedSearch.do?type=cft"><span aria-label="Advanced search" class="fa fa-search"></span>
# <span class="d-none d-lg-inline">Advanced search</span></a>
# </div>
# </li>
# <li class="nav-item mr-2">
# <div>
# <a class="nav-link p-2" href="/epps/prepareCurrentOpportunities.do"><span aria-label="View current opportunities" class="fa fa-search-plus"></span>
# <span class="d-none d-lg-inline">View current opportunities</span></a>
# </div>
# </li>
# <!--// Search -->
# <li class="nav-item dropdown user">
# <div class="d-flex justify-content-end">
# <div>
# <a href="/epps/authenticate/login">
# <button class="btn login float-right" id="loginButton" type="submit">
# <i aria-hidden="true" class="fa fa-sign-in"></i>
# <span>Log in</span>
# </button>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!-- MAIN NAVIGATION MENU -->
# <!-- /.#mainnav || MAIN NAVIGATION MENU-->
# </div>
# </nav>
# </header> <!-- /.header -->
# <script type="text/javascript">
# 	function checkSubmitMain() {
# 		var	quickSearchForm = $("#homeSearch form")[0];
# 		if(checkInputField(quickSearchForm)) {
# 			quickSearchForm.submit();
# 		}
#     	return false;
# 	}
# </script>
# <section class="home-search">
# <div class="container">
# <div class="row align-items-center justify-content-center">
# <div class="col-12" id="homeSearch">
# <form action="/epps/quickSearchAction.do" method="post" name="quickSearchForm" onsubmit=" return checkSubmitMain()" target="_self">
# <div class="form-row">
# </div>
# </form>
# </div>
# </div>
# </div>
# </section>
# <div class="container-fluid pt-2">
# <h1 class="my-4">Welcome to eTendersNI</h1>
# <div class="row">
# <div class="col" id="msgCol">
# </div>
# </div>
# <div class="row">
# <div class="col">
# <noscript>
# <div class="alert alert-warning alert-dismissible" id="NoJavascriptMessage">
# <a aria-label="close" class="close" data-dismiss="alert" href="#">×</a>
# 		For enjoying the full functionality of this application, please ensure that Javascript is enabled in your browser.
# 	</div>
# </noscript>
# </div>
# </div>
# <div class="row">
# <div class="col">
# <script type="text/javascript">
# $j(document).ready(function(){
# 	$j(".openSupplier_Tip").bind("click",function(){
# 		$j(".modalContent_Tip").openInModal({
# 			width:'600',
# 			height:'230'
# 		});
# 	});
# });
# </script>
# <div class="card-wrapper">
# <div class="row">
# <div class="col-12">
# <!-- img src="/epps/images/homepage_neutral.jpg" class="deco" alt="Welcome to the e-Tendering platform" / -->
# 			eTendersNI advertises opportunities for providing goods, services and works to Northern Ireland government department, agencies and arms-length bodies. <br/><br/>To respond to a tender opportunity, and to ensure you receive notifications, you must register as a supplier organisation. The ‘Suppliers new to eTendersNI’ section below provides guidance on registering and learning how to navigate the eTendersNI portal. <br/><br/><strong>If you are new to public sector tendering, advice and assistance is available from a </strong><a href="/epps/viewInfo.do?section=links"><strong>range of organisations.</strong></a>
# </div>
# </div>
# <div class="row">
# <div class="col-12 mt-4">
# <button class="btn btn-secondary btn-sm" data-target="#reqModal" data-toggle="modal" title="Minimum system requirement">
# <span class="fa fa-desktop"></span> Minimum system requirements
# 			</button>
# </div>
# </div>
# </div>
# <!-- Modal -->
# <div aria-hidden="true" aria-labelledby="reqModalLabel" class="modal fade" id="reqModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <!--       <div class="modal-header">
#         <h5 class="modal-title" id="exampleModalLabel">Modal title</h5>
#         <button type="button" class="close" data-dismiss="modal" aria-label="Close">
#           <span aria-hidden="true">&times;</span>
#         </button>
#       </div> -->
# <div class="modal-body">
# <div class="modalContent_Tip">
# <br/><h2>Supplier Tip</h2> <p>Please note that in order to respond to a tender you will need the following software:</p> <br>- Use one of the following web browsers: Microsoft Edge (latest version), Mozilla Firefox (latest version), Google Chrome (latest version), Safari (latest version).<br/>- Have a valid e-mail address<br/>- Java Runtime Environment (version 1.8 or higher).<br/>  - Click on the following link to verify your Java version: <a href="#" onclick="window.open('https://www.java.com/verify'); return false;">https://www.java.com/verify</a><br/>  - Click on the following link to download the latest Java version: <a href="#" onclick="window.open('http://www.java.com/en/download/manual.jsp'); return false;">http://www.java.com/en/download/manual.jsp</a><br/>- Javascript must be enabled in your browser.<br/>  - Click on the following link to check whether Javascript is enabled: <a href="#" onclick="window.open('http://enable-javascript.com/'); return false;">http://enable-javascript.com/</a>
# </br></div>
# </div>
# <!--       <div class="modal-footer">
#         <button type="button" class="btn btn-secondary" data-dismiss="modal">Close</button>
#         <button type="button" class="btn btn-primary">Save changes</button>
#       </div> -->
# </div>
# </div>
# </div>
# <script src="/epps/scripts/sbisdk-all-production.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# 	Sbi.sdk.services.setBaseUrl({
# 	    protocol: 'https'
# 	    , host: 'etendersni.gov.uk'
# 	    , port: '443'
# 	    , contextPath: 'PublicSpagoBI/SpagoBI/'
# 	    , controllerPath: 'servlet/AdapterHTTP'
# 	});
#
# 	$j(function () {
# 		var tabsetSelector = ".tabset";
# 		$j(tabsetSelector).tabs({
# 			collapsible: true, //When all tabs are unchecked on a tabset then the panel will be collapsed
# 			active:false,//Using this  we make all tabs inactive by default
# 			disabled: [ 2 ],//Using this  we make disable the 3rd tab of each tabset
# 			beforeActivate: function (event, ui) {
# 				//It seems that only by triggering the click event we can change the state of an active tab (the plugin api does not provide a better way).
# 				$j(ui.newTab).closest(tabsetSelector).siblings(tabsetSelector).find(".ui-tabs-active .ui-tabs-anchor").trigger("click");
# 			},
# 			activate: function( event, ui ) {
# 				if( $j(ui.newPanel).html()=="" ){
#
# 					var id =$j(ui.newPanel).attr('id');
# 					var documentLabel = id === 'tabs-1' ? 'CfTsClosing' :
# 										id === 'tabs-2' ? 'SubmissionMonthly' :
# 										id === 'tabs-4' ? 'ContractsAwarded' :
# 										id === 'tabs-5' ? 'SuppliersRegPM' : '';
#
# 				   Sbi.sdk.api.injectDocument({
# 						documentLabel: documentLabel
# 						, executionRole: '/spagobi/user/public'
# 						, displayToolbar: false
# 						, displaySliders: false
# 						, target: id
# 						, iframe: {
# 							style: 'border: 0px; width: 100%; height:500px'
# 						}
# 				   		,useExtUI: true
# 			   		});
# 				}
# 			}
# 		});
#
# 	    $j.ajax({
# 	        url: '/epps/home/statistics.do',
# 	        dataType: 'json',
# 	        type: 'get',
# 	        async: true,
# 	        success: function(data){
# 	        	$j('#call_for_tenders_sum').html( data.call_for_tenders );
# 	        	$j('#tender_submissions_sum').html( data.tender_submissions );
# 	        	$j('#supplier_registrations_sum').html( data.supplier_registrations );
# 	        	$j('#contracting_authorities_sum').html( data.contracting_authorities );
# 	        	$j('#awarded_contracts_value_sum').html( (parseFloat(data.awarded_contracts_value / 1000000).toFixed(1)) + " M" );
# 	        	$j('#awarded_contracts_sum').html( data.awarded_contracts );
#
# 	        	$j('#statistics').show();
#
# 	        }
# 	    });
#
#
# 	});
#
# </script>
# <div class="card-wrapper" id="statistics">
# <h2 class="eTenderActivity">eTendersNI activity</h2>
# <div class="row">
# <div class="col-12">
# <div class="multi-tabset">
# <div class="tabset">
# <ul>
# <li><a class="CallTenders Modal_button" href="#tabs-1">
# <span class="fa fa-share"></span> <span><strong id="call_for_tenders_sum"></strong> Call for Tenders</span></a></li>
# <li><a class="TenderSubmission Modal_button" href="#tabs-2">
# <span class="fa fa-reply"></span> <span><strong id="tender_submissions_sum"></strong> Tender Submissions</span></a></li>
# <li><a class=" Modal_button" href="#tabs-3">
# <span class="fa fa-users"></span> <span><strong id="contracting_authorities_sum"></strong> Contracting Authorities</span></a></li>
# </ul>
# <div id="tabs-1"></div>
# <div id="tabs-2"></div>
# <div id="tabs-3"></div>
# </div>
# <div class="tabset">
# <ul>
# <li><a class="Awarded Modal_button" href="#tabs-4">
# <span class="fa fa-gbp"></span> <span><strong id="awarded_contracts_value_sum"></strong> Awarded Contracts Value</span></a></li>
# <li><a class="SupRegister Modal_button" href="#tabs-5">
# <span class="fa fa-users"></span> <span><strong id="supplier_registrations_sum"></strong> Supplier Registrations</span></a></li>
# <li><a class=" Modal_button" href="#tabs-6">
# <span class="fa fa-certificate"></span> <span><strong id="awarded_contracts_sum"></strong> Awarded Contracts</span></a></li>
# </ul>
# <div id="tabs-4"></div>
# <div id="tabs-5"></div>
# <div id="tabs-6"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <iframe src="https://etendersni.gov.uk:443/PublicSpagoBI/SpagoBI//servlet/AdapterHTTP?ACTION_NAME=START_ACTION_PUBLIC_USER&amp;NEW_SESSION=TRUE" style="width: 0; height:0; border: 0px;" title="Bussiness Intelligence"></iframe>
# <div class="row">
# <!--  Left Column -->
# <div class="col-md-5">
# <div class="card-wrapper">
# <div class="row">
# <div class="col-12">
# <h3><span aria-hidden="true" class="fa fa-info-circle"></span>Suppliers new to eTendersNI</h3>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <ul class="square">
# <li>View eTendersNI  <a href="definition/walkthroughs.index.do?selectedItem=definition/walkthroughs.index.do">registration process walkthrough</a></li>
# <li>Obtain, or check if you have a <a href="http://www.dnb.co.uk/forms/new_duns">DUNS number</a></li>
# <li><a href="prepareRegisterEOOrg.do?registerEO=true">Register</a> yourself and your organisation</li>
# <li>Download the Supplier <a href="#" onclick="window.open('viewInfo.do?isPopup=true&amp;section=userManual','name','height=550,width=810,scrollbars=yes,resizable=yes,left=60,top=10')">user manual</a></li>
# <li>View the <a href="prepareAdvancedSearch.do?type=cftFTS">latest Calls for Tenders</a> publications using the search for a relevant tender opportunity</li>
# <li>For <a href="#" onclick="window.open('PrepareContactUsAction.do','name','height=550,width=810,scrollbars=yes,resizable=yes,left=60,top=10')">helpdesk details</a> refer to ‘contact us’ at top of page</li>
# </ul>
# </div>
# </div>
# </div> <!-- ./CARD 01 -->
# </div>
# <!--  Right Column -->
# <div class="col-md-7">
# <div class="card-wrapper">
# <div class="row">
# <div class="col-12">
# <h4>
# <a href="/epps/viewInfo.do?section=newItems">Latest news</a>
# </h4>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <ul class="news">
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4391151">
# <span class="eventDate">
# <span>19</span>
# <span>Aug</span>
# </span>
# 									REMINDER - Construction Supplier Survey on Public Sector Procurement – closing 31st August 2022
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4387657">
# <span class="eventDate">
# <span>17</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - P1628 - Lifford to Castlefin Greenway - Archaeological Consultancy Services Contract
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4367190">
# <span class="eventDate">
# <span>08</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - NWGW L2CF - The detailed design of Lifford to Castlefin Greenway
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4364822">
# <span class="eventDate">
# <span>05</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - NWGW M2QP - The detailed design of Muff to Quigelys Point Greenway
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4345930">
# <span class="eventDate">
# <span>27</span>
# <span>Jul</span>
# </span>
# 									Louth County Council - 09292 - Consultancy support for the development, facilitation and submission of the LOUTH Peace Plus Action Plan
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4335257">
# <span class="eventDate">
# <span>21</span>
# <span>Jul</span>
# </span>
# 									Construction Supplier Survey on Public Sector Procurement
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4333291">
# <span class="eventDate">
# <span>19</span>
# <span>Jul</span>
# </span>
# 									Donegal County Council 1629 - Muff to Quigleys Point Greenway - Geotechnical Investigation Contract
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4333219">
# <span class="eventDate">
# <span>19</span>
# <span>Jul</span>
# </span>
# 									Donegal County Council 1628 - Lifford to Castlefin Greenway - Geotechnical Investigation Contract
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4301107">
# <span class="eventDate">
# <span>27</span>
# <span>Jun</span>
# </span>
# 									North West City Region RFT  217329 -  Provision of Services to develop an Investment Concept based on the deliverables in the North West Regional Energy Strategy Roadmap
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4297550">
# <span class="eventDate">
# <span>23</span>
# <span>Jun</span>
# </span>
# 									Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs Ref 217100 Barrier Removal and Replacement - Dresnagh Barrier Removal and Replacement Works
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4288735">
# <span class="eventDate">
# <span>17</span>
# <span>Jun</span>
# </span>
# 									Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs - Riparian Tree Planting, Fencing and Instream Works on Finn River
# 								</a>
# </li>
# </ul>
# </div>
# </div>
# </div> <!-- ./CARD 02 -->
# </div>
# </div>
# </div>
# </div>
# </div><!-- /.container-fluid -->
# <script type="text/javascript">
#
# 	    $j('document').ready(function(ev){
# 	    	$j("a.PopUp").click(function(){
# 	    		PopUpOpts = {
# 	        		windowname: 'popupwindow',
# 	        		width:		810,
# 	        		height:		600,
# 	        		scroll:		1,
# 	        		resizable:	0
# 	        	};
# 	           	$j(this).PopUp(this.href, PopUpOpts);
# 	            return false;
# 	        });
# 	    });
#
# 	</script>
# <footer>
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm">
# <ul class="list-unstyled">
# <li>
# <a href="/epps/prepareCurrentOpportunities.do">View current opportunities</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?section=eproc">eTendersNI FAQ</a>
# </li>
# <li>
# <a href="/epps/definition/walkthroughs.index.do">Walkthrough Help Guides</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?section=statistics">Statistics</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?section=calendar">Events calendar</a>
# </li>
# </ul>
# </div>
# <div class="col-sm">
# <ul class="list-unstyled">
# <li>
# <a href="/epps/viewInfo.do?section=eproc">Public procurement policy</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?section=newItems">News</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?section=links">Relevant links</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?section=faq">Procurement pipelines</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?section=thresholds">Supplier information on public sector tendering</a>
# </li>
# </ul>
# </div>
# <div class="col-sm">
# <ul class="list-unstyled">
# <li><a href="/epps/preparation_offline_tool/TenderPreparationTool.zip">
# 								Download tender preparation tool</a>
# </li>
# <li id="Help">
# <a class="PopUp" href="/epps/viewInfo.do?isPopup=true&amp;section=userManual">Help</a>
# </li>
# <li id="About">
# <a class="PopUp" href="/epps/DisplayHeaderStaticTextAction.do">About</a>
# </li>
# <li class="Last" id="Contact">
# <a class="PopUp" href="/epps/PrepareContactUsAction.do">Contact us</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col text-center">
# <span>Copyright © European Dynamics - Last update: 23 August 2022</span>
# </div>
# </div>
# </div>
# </footer>
# <!-- Footer // -->
# </body>
# </html>

# %%
results = s.find_all("div", class_="col-12")
print(results)
# Out:
# [<div class="flex-column col-12 p-0">
# <div class="row no-gutters p-2 align-items-center">
# <div class="col-6">
# <a class="navbar-brand mr-0 py-lg-1 py-xl-1 px-lg-2 px-xl-2" href="/epps">
# <img alt="Ηomepage" class="mr-lg-2 mr-xl-2 img-fluid " src="/epps/images/bt/NI-logo.gif"/>
# <img alt="Ηomepage" class="mr-lg-2 mr-xl-2 img-fluid d-none d-lg-inline-block" src="/epps/images/bt/NI-logo-2_1.png"/>
# </a>
# </div>
# <div class="col-6">
# <ul class="navbar-nav flex-row justify-content-end">
# <!-- Search -->
# <script type="text/javascript">
# 	function checkSubmit() {
# 		var	quicSearchForm = document.forms["quickSearchForm"];
# 		var col = document.getElementsByName("searchSelect")[0];
# 		if (col.selectedIndex != 0) {
# 			if(checkInputField(quicSearchForm))quicSearchForm.submit();
#     	}
#     	return false;
# 	}
#
# 	function checkInputField(form){
# 		var input = form[1].value;
# 		if(containForbidenChars(input)){
# 			form[1].value = '*';
# 			alert("An invalid character was provided for search. Invalid characters include: <, >, &, % .");
# 			return false;
# 		}
# 		return true;
# 	}
#
# 	function containForbidenChars(input){
#     	return input.indexOf("<")!=-1 || input.indexOf(">")!=-1 || input.indexOf("%")!=-1 || input.indexOf("&")!=-1;
#     }
# </script>
# <script type="text/javascript">
# 	$(document).ready(function() {
#
# 	});
#
# 	function openForm() {
# 		document.getElementById("simple-search").style.height = "100%";
# 	}
# 	function closeForm() {
# 		document.getElementById("simple-search").style.height = "0%";
# 	}
# </script>
# <li class="nav-item mr-2">
# <div>
# <a class="nav-link p-2" href="/epps/prepareAdvancedSearch.do?type=cft"><span aria-label="Advanced search" class="fa fa-search"></span>
# <span class="d-none d-lg-inline">Advanced search</span></a>
# </div>
# </li>
# <li class="nav-item mr-2">
# <div>
# <a class="nav-link p-2" href="/epps/prepareCurrentOpportunities.do"><span aria-label="View current opportunities" class="fa fa-search-plus"></span>
# <span class="d-none d-lg-inline">View current opportunities</span></a>
# </div>
# </li>
# <!--// Search -->
# <li class="nav-item dropdown user">
# <div class="d-flex justify-content-end">
# <div>
# <a href="/epps/authenticate/login">
# <button class="btn login float-right" id="loginButton" type="submit">
# <i aria-hidden="true" class="fa fa-sign-in"></i>
# <span>Log in</span>
# </button>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!-- MAIN NAVIGATION MENU -->
# <!-- /.#mainnav || MAIN NAVIGATION MENU-->
# </div>, <div class="col-12" id="homeSearch">
# <form action="/epps/quickSearchAction.do" method="post" name="quickSearchForm" onsubmit=" return checkSubmitMain()" target="_self">
# <div class="form-row">
# </div>
# </form>
# </div>, <div class="col-12">
# <!-- img src="/epps/images/homepage_neutral.jpg" class="deco" alt="Welcome to the e-Tendering platform" / -->
# 			eTendersNI advertises opportunities for providing goods, services and works to Northern Ireland government department, agencies and arms-length bodies. <br/><br/>To respond to a tender opportunity, and to ensure you receive notifications, you must register as a supplier organisation. The ‘Suppliers new to eTendersNI’ section below provides guidance on registering and learning how to navigate the eTendersNI portal. <br/><br/><strong>If you are new to public sector tendering, advice and assistance is available from a </strong><a href="/epps/viewInfo.do?section=links"><strong>range of organisations.</strong></a>
# </div>, <div class="col-12 mt-4">
# <button class="btn btn-secondary btn-sm" data-target="#reqModal" data-toggle="modal" title="Minimum system requirement">
# <span class="fa fa-desktop"></span> Minimum system requirements
# 			</button>
# </div>, <div class="col-12">
# <div class="multi-tabset">
# <div class="tabset">
# <ul>
# <li><a class="CallTenders Modal_button" href="#tabs-1">
# <span class="fa fa-share"></span> <span><strong id="call_for_tenders_sum"></strong> Call for Tenders</span></a></li>
# <li><a class="TenderSubmission Modal_button" href="#tabs-2">
# <span class="fa fa-reply"></span> <span><strong id="tender_submissions_sum"></strong> Tender Submissions</span></a></li>
# <li><a class=" Modal_button" href="#tabs-3">
# <span class="fa fa-users"></span> <span><strong id="contracting_authorities_sum"></strong> Contracting Authorities</span></a></li>
# </ul>
# <div id="tabs-1"></div>
# <div id="tabs-2"></div>
# <div id="tabs-3"></div>
# </div>
# <div class="tabset">
# <ul>
# <li><a class="Awarded Modal_button" href="#tabs-4">
# <span class="fa fa-gbp"></span> <span><strong id="awarded_contracts_value_sum"></strong> Awarded Contracts Value</span></a></li>
# <li><a class="SupRegister Modal_button" href="#tabs-5">
# <span class="fa fa-users"></span> <span><strong id="supplier_registrations_sum"></strong> Supplier Registrations</span></a></li>
# <li><a class=" Modal_button" href="#tabs-6">
# <span class="fa fa-certificate"></span> <span><strong id="awarded_contracts_sum"></strong> Awarded Contracts</span></a></li>
# </ul>
# <div id="tabs-4"></div>
# <div id="tabs-5"></div>
# <div id="tabs-6"></div>
# </div>
# </div>
# </div>, <div class="col-12">
# <h3><span aria-hidden="true" class="fa fa-info-circle"></span>Suppliers new to eTendersNI</h3>
# </div>, <div class="col-12">
# <ul class="square">
# <li>View eTendersNI  <a href="definition/walkthroughs.index.do?selectedItem=definition/walkthroughs.index.do">registration process walkthrough</a></li>
# <li>Obtain, or check if you have a <a href="http://www.dnb.co.uk/forms/new_duns">DUNS number</a></li>
# <li><a href="prepareRegisterEOOrg.do?registerEO=true">Register</a> yourself and your organisation</li>
# <li>Download the Supplier <a href="#" onclick="window.open('viewInfo.do?isPopup=true&amp;section=userManual','name','height=550,width=810,scrollbars=yes,resizable=yes,left=60,top=10')">user manual</a></li>
# <li>View the <a href="prepareAdvancedSearch.do?type=cftFTS">latest Calls for Tenders</a> publications using the search for a relevant tender opportunity</li>
# <li>For <a href="#" onclick="window.open('PrepareContactUsAction.do','name','height=550,width=810,scrollbars=yes,resizable=yes,left=60,top=10')">helpdesk details</a> refer to ‘contact us’ at top of page</li>
# </ul>
# </div>, <div class="col-12">
# <h4>
# <a href="/epps/viewInfo.do?section=newItems">Latest news</a>
# </h4>
# </div>, <div class="col-12">
# <ul class="news">
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4391151">
# <span class="eventDate">
# <span>19</span>
# <span>Aug</span>
# </span>
# 									REMINDER - Construction Supplier Survey on Public Sector Procurement – closing 31st August 2022
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4387657">
# <span class="eventDate">
# <span>17</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - P1628 - Lifford to Castlefin Greenway - Archaeological Consultancy Services Contract
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4367190">
# <span class="eventDate">
# <span>08</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - NWGW L2CF - The detailed design of Lifford to Castlefin Greenway
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4364822">
# <span class="eventDate">
# <span>05</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - NWGW M2QP - The detailed design of Muff to Quigelys Point Greenway
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4345930">
# <span class="eventDate">
# <span>27</span>
# <span>Jul</span>
# </span>
# 									Louth County Council - 09292 - Consultancy support for the development, facilitation and submission of the LOUTH Peace Plus Action Plan
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4335257">
# <span class="eventDate">
# <span>21</span>
# <span>Jul</span>
# </span>
# 									Construction Supplier Survey on Public Sector Procurement
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4333291">
# <span class="eventDate">
# <span>19</span>
# <span>Jul</span>
# </span>
# 									Donegal County Council 1629 - Muff to Quigleys Point Greenway - Geotechnical Investigation Contract
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4333219">
# <span class="eventDate">
# <span>19</span>
# <span>Jul</span>
# </span>
# 									Donegal County Council 1628 - Lifford to Castlefin Greenway - Geotechnical Investigation Contract
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4301107">
# <span class="eventDate">
# <span>27</span>
# <span>Jun</span>
# </span>
# 									North West City Region RFT  217329 -  Provision of Services to develop an Investment Concept based on the deliverables in the North West Regional Energy Strategy Roadmap
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4297550">
# <span class="eventDate">
# <span>23</span>
# <span>Jun</span>
# </span>
# 									Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs Ref 217100 Barrier Removal and Replacement - Dresnagh Barrier Removal and Replacement Works
# 								</a>
# </li>
# <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4288735">
# <span class="eventDate">
# <span>17</span>
# <span>Jun</span>
# </span>
# 									Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs - Riparian Tree Planting, Fencing and Instream Works on Finn River
# 								</a>
# </li>
# </ul>
# </div>]

# %%
date = []
company = []
link =[]

# %%
list_tags = s.find_all("li")
print(list_tags)
# Out:
# [<li class="nav-item mr-2">
# <div>
# <a class="nav-link p-2" href="/epps/prepareAdvancedSearch.do?type=cft"><span aria-label="Advanced search" class="fa fa-search"></span>
# <span class="d-none d-lg-inline">Advanced search</span></a>
# </div>
# </li>, <li class="nav-item mr-2">
# <div>
# <a class="nav-link p-2" href="/epps/prepareCurrentOpportunities.do"><span aria-label="View current opportunities" class="fa fa-search-plus"></span>
# <span class="d-none d-lg-inline">View current opportunities</span></a>
# </div>
# </li>, <li class="nav-item dropdown user">
# <div class="d-flex justify-content-end">
# <div>
# <a href="/epps/authenticate/login">
# <button class="btn login float-right" id="loginButton" type="submit">
# <i aria-hidden="true" class="fa fa-sign-in"></i>
# <span>Log in</span>
# </button>
# </a>
# </div>
# </div>
# </li>, <li><a class="CallTenders Modal_button" href="#tabs-1">
# <span class="fa fa-share"></span> <span><strong id="call_for_tenders_sum"></strong> Call for Tenders</span></a></li>, <li><a class="TenderSubmission Modal_button" href="#tabs-2">
# <span class="fa fa-reply"></span> <span><strong id="tender_submissions_sum"></strong> Tender Submissions</span></a></li>, <li><a class=" Modal_button" href="#tabs-3">
# <span class="fa fa-users"></span> <span><strong id="contracting_authorities_sum"></strong> Contracting Authorities</span></a></li>, <li><a class="Awarded Modal_button" href="#tabs-4">
# <span class="fa fa-gbp"></span> <span><strong id="awarded_contracts_value_sum"></strong> Awarded Contracts Value</span></a></li>, <li><a class="SupRegister Modal_button" href="#tabs-5">
# <span class="fa fa-users"></span> <span><strong id="supplier_registrations_sum"></strong> Supplier Registrations</span></a></li>, <li><a class=" Modal_button" href="#tabs-6">
# <span class="fa fa-certificate"></span> <span><strong id="awarded_contracts_sum"></strong> Awarded Contracts</span></a></li>, <li>View eTendersNI  <a href="definition/walkthroughs.index.do?selectedItem=definition/walkthroughs.index.do">registration process walkthrough</a></li>, <li>Obtain, or check if you have a <a href="http://www.dnb.co.uk/forms/new_duns">DUNS number</a></li>, <li><a href="prepareRegisterEOOrg.do?registerEO=true">Register</a> yourself and your organisation</li>, <li>Download the Supplier <a href="#" onclick="window.open('viewInfo.do?isPopup=true&amp;section=userManual','name','height=550,width=810,scrollbars=yes,resizable=yes,left=60,top=10')">user manual</a></li>, <li>View the <a href="prepareAdvancedSearch.do?type=cftFTS">latest Calls for Tenders</a> publications using the search for a relevant tender opportunity</li>, <li>For <a href="#" onclick="window.open('PrepareContactUsAction.do','name','height=550,width=810,scrollbars=yes,resizable=yes,left=60,top=10')">helpdesk details</a> refer to ‘contact us’ at top of page</li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4391151">
# <span class="eventDate">
# <span>19</span>
# <span>Aug</span>
# </span>
# 									REMINDER - Construction Supplier Survey on Public Sector Procurement – closing 31st August 2022
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4387657">
# <span class="eventDate">
# <span>17</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - P1628 - Lifford to Castlefin Greenway - Archaeological Consultancy Services Contract
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4367190">
# <span class="eventDate">
# <span>08</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - NWGW L2CF - The detailed design of Lifford to Castlefin Greenway
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4364822">
# <span class="eventDate">
# <span>05</span>
# <span>Aug</span>
# </span>
# 									Donegal County Council - NWGW M2QP - The detailed design of Muff to Quigelys Point Greenway
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4345930">
# <span class="eventDate">
# <span>27</span>
# <span>Jul</span>
# </span>
# 									Louth County Council - 09292 - Consultancy support for the development, facilitation and submission of the LOUTH Peace Plus Action Plan
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4335257">
# <span class="eventDate">
# <span>21</span>
# <span>Jul</span>
# </span>
# 									Construction Supplier Survey on Public Sector Procurement
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4333291">
# <span class="eventDate">
# <span>19</span>
# <span>Jul</span>
# </span>
# 									Donegal County Council 1629 - Muff to Quigleys Point Greenway - Geotechnical Investigation Contract
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4333219">
# <span class="eventDate">
# <span>19</span>
# <span>Jul</span>
# </span>
# 									Donegal County Council 1628 - Lifford to Castlefin Greenway - Geotechnical Investigation Contract
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4301107">
# <span class="eventDate">
# <span>27</span>
# <span>Jun</span>
# </span>
# 									North West City Region RFT  217329 -  Provision of Services to develop an Investment Concept based on the deliverables in the North West Regional Energy Strategy Roadmap
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4297550">
# <span class="eventDate">
# <span>23</span>
# <span>Jun</span>
# </span>
# 									Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs Ref 217100 Barrier Removal and Replacement - Dresnagh Barrier Removal and Replacement Works
# 								</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?sec=newItems&amp;entryId=4288735">
# <span class="eventDate">
# <span>17</span>
# <span>Jun</span>
# </span>
# 									Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs - Riparian Tree Planting, Fencing and Instream Works on Finn River
# 								</a>
# </li>, <li>
# <a href="/epps/prepareCurrentOpportunities.do">View current opportunities</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?section=eproc">eTendersNI FAQ</a>
# </li>, <li>
# <a href="/epps/definition/walkthroughs.index.do">Walkthrough Help Guides</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?section=statistics">Statistics</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?section=calendar">Events calendar</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?section=eproc">Public procurement policy</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?section=newItems">News</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?section=links">Relevant links</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?section=faq">Procurement pipelines</a>
# </li>, <li>
# <a href="/epps/viewInfo.do?section=thresholds">Supplier information on public sector tendering</a>
# </li>, <li><a href="/epps/preparation_offline_tool/TenderPreparationTool.zip">
# 								Download tender preparation tool</a>
# </li>, <li id="Help">
# <a class="PopUp" href="/epps/viewInfo.do?isPopup=true&amp;section=userManual">Help</a>
# </li>, <li id="About">
# <a class="PopUp" href="/epps/DisplayHeaderStaticTextAction.do">About</a>
# </li>, <li class="Last" id="Contact">
# <a class="PopUp" href="/epps/PrepareContactUsAction.do">Contact us</a>
# </li>]

# %%
for i in list_tags:
  block = i.find('a')
  k = block.find_all('span')
  if(block.find('span',attrs={'class': 'eventDate'}) != None):
    st = ""
    for j in range(1,3):
      s = k[j]
      st += s.text
    date.append(st)
    c = block.text.split('\n')[5]
    c1 = c.strip("\t")
    c1 = c.split("\r")
    company.append(c1)
    s1 = "https://etendersni.gov.uk"
    s2 = block['href']
    lin = "".join([s1,s2])
    link.append(lin)

# %%
print(date)
print(company)
print(link)
# Out:
# ['19Aug', '17Aug', '08Aug', '05Aug', '27Jul', '21Jul', '19Jul', '19Jul', '27Jun', '23Jun', '17Jun']
# [['\t\t\t\t\t\t\t\t\tREMINDER - Construction Supplier Survey on Public Sector Procurement – closing 31st August 2022', ''], ['\t\t\t\t\t\t\t\t\tDonegal County Council - P1628 - Lifford to Castlefin Greenway - Archaeological Consultancy Services Contract ', ''], ['\t\t\t\t\t\t\t\t\tDonegal County Council - NWGW L2CF - The detailed design of Lifford to Castlefin Greenway', ''], ['\t\t\t\t\t\t\t\t\tDonegal County Council - NWGW M2QP - The detailed design of Muff to Quigelys Point Greenway ', ''], ['\t\t\t\t\t\t\t\t\tLouth County Council - 09292 - Consultancy support for the development, facilitation and submission of the LOUTH Peace Plus Action Plan', ''], ['\t\t\t\t\t\t\t\t\tConstruction Supplier Survey on Public Sector Procurement', ''], ['\t\t\t\t\t\t\t\t\tDonegal County Council 1629 - Muff to Quigleys Point Greenway - Geotechnical Investigation Contract ', ''], ['\t\t\t\t\t\t\t\t\tDonegal County Council 1628 - Lifford to Castlefin Greenway - Geotechnical Investigation Contract ', ''], ['\t\t\t\t\t\t\t\t\tNorth West City Region RFT  217329 -  Provision of Services to develop an Investment Concept based on the deliverables in the North West Regional Energy Strategy Roadmap', ''], ['\t\t\t\t\t\t\t\t\tLoughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs Ref 217100 Barrier Removal and Replacement - Dresnagh Barrier Removal and Replacement Works', ''], ['\t\t\t\t\t\t\t\t\tLoughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs - Riparian Tree Planting, Fencing and Instream Works on Finn River ', '']]
# ['https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4391151', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4387657', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4367190', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4364822', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4345930', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4335257', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4333291', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4333219', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4301107', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4297550', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4288735']

# %%
new_company=[]
flat_list = [item for sublist in company for item in sublist]
for i in flat_list:
  k=i.split("\t")
  k=k[-1].split('\r')
  while '' in k:
    k.remove('')
  new_company.append(k)
new_company=[item for sublist in new_company for item in sublist]

# %%
print(date)
print(new_company)
print(link)
# Out:
# ['19Aug', '17Aug', '08Aug', '05Aug', '27Jul', '21Jul', '19Jul', '19Jul', '27Jun', '23Jun', '17Jun']
# ['REMINDER - Construction Supplier Survey on Public Sector Procurement – closing 31st August 2022', 'Donegal County Council - P1628 - Lifford to Castlefin Greenway - Archaeological Consultancy Services Contract ', 'Donegal County Council - NWGW L2CF - The detailed design of Lifford to Castlefin Greenway', 'Donegal County Council - NWGW M2QP - The detailed design of Muff to Quigelys Point Greenway ', 'Louth County Council - 09292 - Consultancy support for the development, facilitation and submission of the LOUTH Peace Plus Action Plan', 'Construction Supplier Survey on Public Sector Procurement', 'Donegal County Council 1629 - Muff to Quigleys Point Greenway - Geotechnical Investigation Contract ', 'Donegal County Council 1628 - Lifford to Castlefin Greenway - Geotechnical Investigation Contract ', 'North West City Region RFT  217329 -  Provision of Services to develop an Investment Concept based on the deliverables in the North West Regional Energy Strategy Roadmap', 'Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs Ref 217100 Barrier Removal and Replacement - Dresnagh Barrier Removal and Replacement Works', 'Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs - Riparian Tree Planting, Fencing and Instream Works on Finn River ']
# ['https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4391151', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4387657', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4367190', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4364822', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4345930', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4335257', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4333291', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4333219', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4301107', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4297550', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4288735']

# %%
import csv
fields = ['Date','Title','Link']
rows=[]
for i in range(len(company)):
  rows.append([date[i], new_company[i], link[i]])
print(rows)
# Out:
# [['19Aug', 'REMINDER - Construction Supplier Survey on Public Sector Procurement – closing 31st August 2022', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4391151'], ['17Aug', 'Donegal County Council - P1628 - Lifford to Castlefin Greenway - Archaeological Consultancy Services Contract ', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4387657'], ['08Aug', 'Donegal County Council - NWGW L2CF - The detailed design of Lifford to Castlefin Greenway', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4367190'], ['05Aug', 'Donegal County Council - NWGW M2QP - The detailed design of Muff to Quigelys Point Greenway ', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4364822'], ['27Jul', 'Louth County Council - 09292 - Consultancy support for the development, facilitation and submission of the LOUTH Peace Plus Action Plan', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4345930'], ['21Jul', 'Construction Supplier Survey on Public Sector Procurement', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4335257'], ['19Jul', 'Donegal County Council 1629 - Muff to Quigleys Point Greenway - Geotechnical Investigation Contract ', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4333291'], ['19Jul', 'Donegal County Council 1628 - Lifford to Castlefin Greenway - Geotechnical Investigation Contract ', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4333219'], ['27Jun', 'North West City Region RFT  217329 -  Provision of Services to develop an Investment Concept based on the deliverables in the North West Regional Energy Strategy Roadmap', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4301107'], ['23Jun', 'Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs Ref 217100 Barrier Removal and Replacement - Dresnagh Barrier Removal and Replacement Works', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4297550'], ['17Jun', 'Loughs Agency / Ghníomhaireacht na Lochanna /Factrie fur Loughs - Riparian Tree Planting, Fencing and Instream Works on Finn River ', 'https://etendersni.gov.uk/epps/viewInfo.do?sec=newItems&entryId=4288735']]

# %%
with open("tenders_data.csv",'w',newline = "") as output:
  writer = csv.writer(output)
  writer.writerow(fields)
  writer.writerows(rows)
